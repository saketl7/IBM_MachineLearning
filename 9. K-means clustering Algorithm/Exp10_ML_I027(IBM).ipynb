# %% [markdown]
# <a href="https://colab.research.google.com/github/saketlakhotia17/IBM_MachineLearning/blob/main/9.%20K-means%20clustering%20Algorithm/Exp10_ML_I027(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 10 - K-means clustering Algorithm

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
#creating dataset
x,y = make_blobs(n_samples=150, n_features=2, centers=3, cluster_std = 0.8,shuffle = True, random_state=0)

# %%
x.shape
# Out:
# (150, 2)

# %%
y.shape
# Out:
# (150,)

# %%
plt.scatter(x[:,0],x[:,1],c = 'white', marker='o',edgecolors='black',s=50)

# %%
#creating dataset
x,y = make_blobs(n_samples=150, n_features=2, centers=3, cluster_std = 0.5,shuffle = True, random_state=0)

# %%
plt.scatter(x[:,0],x[:,1],c = 'white', marker='o',edgecolors='black',s=50)

# %%
x,y = make_blobs(n_samples=150, n_features=2, centers=4, cluster_std = 0.5,shuffle = True, random_state=0)

# %%
plt.scatter(x[:,0],x[:,1],c = 'white', marker='o',edgecolors='black',s=50)

# %%
x,y = make_blobs(n_samples=150, n_features=2, centers=3, cluster_std = 0.8,shuffle = True, random_state=0)

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=3, init='random', max_iter=1, tol=0.0001, random_state=0)
y_km = km.fit_predict(x)

# %%
#plot 3 clusters

plt.scatter(x[y_km==0,0], x[y_km==0,1], s = 50, c = 'green', marker ='s', edgecolors='black', label = 'Cluster 1')
plt.scatter(x[y_km==1,0], x[y_km==1,1], s = 50, c = 'orange', marker ='o', edgecolors='black', label = 'Cluster 2')
plt.scatter(x[y_km==2,0], x[y_km==2,1], s = 50, c = 'blue', marker ='v', edgecolors='black', label = 'Cluster 3')

#plot mean values of each cluster
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1], s=250, marker='*', c='red', edgecolors='black', label='Mean')

# %%
#k1 (iteration = 1)
km.cluster_centers_
# Out:
# array([[ 0.66939858,  4.44244355],
#        [ 2.03699481,  1.32441456],
#        [-1.77827877,  2.91929619]])

# %%
km = KMeans(n_clusters=3, init='random', max_iter=10, tol=0.0001, random_state=0)
y_km = km.fit_predict(x)

#plot 3 clusters

plt.scatter(x[y_km==0,0], x[y_km==0,1], s = 50, c = 'green', marker ='s', edgecolors='black', label = 'Cluster 1')
plt.scatter(x[y_km==1,0], x[y_km==1,1], s = 50, c = 'orange', marker ='o', edgecolors='black', label = 'Cluster 2')
plt.scatter(x[y_km==2,0], x[y_km==2,1], s = 50, c = 'blue', marker ='v', edgecolors='black', label = 'Cluster 3')

#plot mean values of each cluster
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1], s=250, marker='*', c='red', edgecolors='black', label='Mean')

# %%
#k10 (iteration = 10)
km.cluster_centers_
# Out:
# array([[-1.75331622,  2.9376426 ],
#        [ 0.84069413,  4.35679782],
#        [ 2.05130138,  1.06134965]])

# %%
km = KMeans(n_clusters=3, init='random', max_iter=100, tol=0.0001, random_state=0)
y_km = km.fit_predict(x)

#plot 3 clusters

plt.scatter(x[y_km==0,0], x[y_km==0,1], s = 50, c = 'green', marker ='s', edgecolors='black', label = 'Cluster 1')
plt.scatter(x[y_km==1,0], x[y_km==1,1], s = 50, c = 'orange', marker ='o', edgecolors='black', label = 'Cluster 2')
plt.scatter(x[y_km==2,0], x[y_km==2,1], s = 50, c = 'blue', marker ='v', edgecolors='black', label = 'Cluster 3')

#plot mean values of each cluster
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1], s=250, marker='*', c='red', edgecolors='black', label='Mean')
plt.legend(scatterpoints=1)

# %%
#k100 (iteration = 100)
km.cluster_centers_
# Out:
# array([[-1.75331622,  2.9376426 ],
#        [ 0.84069413,  4.35679782],
#        [ 2.05130138,  1.06134965]])

# %%
#Determine the number of clusters
distortion = []
for i in range(1,11):
  km = KMeans(n_clusters=i, init = 'random', max_iter=100, tol=0.0001, random_state=0)
  km.fit(x)
  distortion.append(km.inertia_)

plt.plot(range(1,11), distortion, marker = 'o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
# Out:
# Text(0, 0.5, 'Distortion')

# %% [markdown]
# # Conclusion
# 1. Dataset is created for 3 clusters and cluster stanaderd deviation of point 8.
# 2. Kmeans algorithm is used for different number of iterations. Mean value of each cluster changes with the number of iterations.
# 3. After 10 iterations there is no change in the mean value of all 3 clusters. This shows that there is no redistribution of data points among clusters.
# 4. To decide the number of clusters, elbow method is used. Ot is shown that there is no appreciable reduction in error after the number of clusters is made 3.
# 5. The error reduces drastically when the cluster number is changed from 1 to 3. Therefore it can be concluded that 3 clusters are enough for dataset.
